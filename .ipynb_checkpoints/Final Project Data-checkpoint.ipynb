# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab

# %%
epi = pd.read_csv("Results_Epidural Hemorrhage Detection_2020-11-16_21.31.26.148.csv", error_bad_lines=False)
epi.head()
# Out:
# C:\Users\hafid\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Case ID            Origin                                         URL  \
# 0  1196514  ID_004c4b319.jpg  https://go.centaurlabs.com/problem/1196514
# 1  1196682  ID_0237b835f.jpg  https://go.centaurlabs.com/problem/1196682
# 2  1196477  ID_02e2d273d.jpg  https://go.centaurlabs.com/problem/1196477
# 3  1196612  ID_02f37ce84.jpg  https://go.centaurlabs.com/problem/1196612
# 4  1196612  ID_02f37ce84.jpg  https://go.centaurlabs.com/problem/1196612
#
#   Labeling State                                         All Labels  \
# 0        Labeled  ['[{"x": 0.40818718, "y": 0.8623607}, {"x": 0....
# 1          Ready  ['[{"x": 0.62959146, "y": 0.720186}, {"x": 0.6...
# 2        Labeled  ['[{"x": 0.35205495, "y": 0.34680602}, {"x": 0...
# 3          Ready  ['[{"x": 0.3680166, "y": 0.48387372}, {"x": 0....
# 4          Ready  ['[{"x": 0.3680166, "y": 0.48387372}, {"x": 0....
#
#    Total Reads  Total Qualified Reads  \
# 0         19.0                    5.0
# 1         51.0                   28.0
# 2         22.0                    6.0
# 3         51.0                   29.0
# 4         51.0                   29.0
#
#                                       Majority Label  Number of ROIs  \
# 0  [{"x": 0.537109375, "y": 0.89453125}, {"x": 0....             1.0
# 1  [{"x": 0.654296875, "y": 0.724609375}, {"x": 0...             1.0
# 2  [{"x": 0.46484375, "y": 0.357421875}, {"x": 0....             1.0
# 3  [{"x": 0.431640625, "y": 0.607421875}, {"x": 0...             2.0
# 4  [{"x": 0.353515625, "y": 0.59765625}, {"x": 0....             2.0
#
#                                        Correct Label  Difficulty  Agreement  \
# 0  [[{'x': 0.537109375, 'y': 0.89453125}, {'x': 0...        0.00   0.968851
# 1                                                NaN         NaN   0.063519
# 2  [[{'x': 0.46484375, 'y': 0.357421875}, {'x': 0...        0.06   0.710300
# 3                                                NaN         NaN   0.264134
# 4                                                NaN         NaN   0.264134
#
#   Comments  Internal Notes
# 0      NaN             NaN
# 1      NaN             NaN
# 2      NaN             NaN
# 3      NaN             NaN
# 4      NaN             NaN

# %%
def isNaN(string):
    return string != string

# %%
new_epi = epi[(epi['Majority Label'] != '[]') | (epi['Correct Label'].notna()) & (epi['Correct Label'] != '[[], []]') ]

# %%
new_epi
# Out:
#      Case ID            Origin                                         URL  \
# 0    1196514  ID_004c4b319.jpg  https://go.centaurlabs.com/problem/1196514
# 1    1196682  ID_0237b835f.jpg  https://go.centaurlabs.com/problem/1196682
# 2    1196477  ID_02e2d273d.jpg  https://go.centaurlabs.com/problem/1196477
# 3    1196612  ID_02f37ce84.jpg  https://go.centaurlabs.com/problem/1196612
# 4    1196612  ID_02f37ce84.jpg  https://go.centaurlabs.com/problem/1196612
# ..       ...               ...                                         ...
# 589  1196596  ID_a297d5101.jpg  https://go.centaurlabs.com/problem/1196596
# 590  1196523  ID_aa6b7bf5d.jpg  https://go.centaurlabs.com/problem/1196523
# 602  1196860  ID_f82e15eb5.jpg  https://go.centaurlabs.com/problem/1196860
# 608  1196539  ID_d9bfa60ed.jpg  https://go.centaurlabs.com/problem/1196539
# 609  1196955  ID_fa2874be0.jpg  https://go.centaurlabs.com/problem/1196955
#
#     Labeling State                                         All Labels  \
# 0          Labeled  ['[{"x": 0.40818718, "y": 0.8623607}, {"x": 0....
# 1            Ready  ['[{"x": 0.62959146, "y": 0.720186}, {"x": 0.6...
# 2          Labeled  ['[{"x": 0.35205495, "y": 0.34680602}, {"x": 0...
# 3            Ready  ['[{"x": 0.3680166, "y": 0.48387372}, {"x": 0....
# 4            Ready  ['[{"x": 0.3680166, "y": 0.48387372}, {"x": 0....
# ..             ...                                                ...
# 589        Labeled  ['[{"x": 0.75402844, "y": 0.68062687}, {"x": 0...
# 590        Labeled  ['[{"x": 0.2169128, "y": 0.3310322}, {"x": 0.2...
# 602        Labeled  ['[{"x": 0.429657, "y": 0.864296}, {"x": 0.487...
# 608        Labeled          ['[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]']
# 609        Labeled               ['[]' '[]' '[]' '[]' '[]' '[]' '[]']
#
#      Total Reads  Total Qualified Reads  \
# 0           19.0                    5.0
# 1           51.0                   28.0
# 2           22.0                    6.0
# 3           51.0                   29.0
# 4           51.0                   29.0
# ..           ...                    ...
# 589         18.0                    5.0
# 590         21.0                    5.0
# 602         17.0                    5.0
# 608         20.0                    8.0
# 609         18.0                    7.0
#
#                                         Majority Label  Number of ROIs  \
# 0    [{"x": 0.537109375, "y": 0.89453125}, {"x": 0....             1.0
# 1    [{"x": 0.654296875, "y": 0.724609375}, {"x": 0...             1.0
# 2    [{"x": 0.46484375, "y": 0.357421875}, {"x": 0....             1.0
# 3    [{"x": 0.431640625, "y": 0.607421875}, {"x": 0...             2.0
# 4    [{"x": 0.353515625, "y": 0.59765625}, {"x": 0....             2.0
# ..                                                 ...             ...
# 589                                                 []             0.0
# 590                                                 []             0.0
# 602                                                 []             0.0
# 608                                                 []             0.0
# 609                                                 []             0.0
#
#                                          Correct Label  Difficulty  Agreement  \
# 0    [[{'x': 0.537109375, 'y': 0.89453125}, {'x': 0...        0.00   0.968851
# 1                                                  NaN         NaN   0.063519
# 2    [[{'x': 0.46484375, 'y': 0.357421875}, {'x': 0...        0.06   0.710300
# 3                                                  NaN         NaN   0.264134
# 4                                                  NaN         NaN   0.264134
# ..                                                 ...         ...        ...
# 589  [[{'x': 0.541015625, 'y': 0.8125}, {'x': 0.541...        0.20   0.800000
# 590  [[{'x': 0.220703125, 'y': 0.451171875}, {'x': ...        0.40   0.800000
# 602  [[{'x': 0.48046875, 'y': 0.8828125}, {'x': 0.4...        0.20   0.800000
# 608  [[{'x': 0.443359375, 'y': 0.810546875}, {'x': ...        0.12   1.000000
# 609  [[{'x': 0.37890625, 'y': 0.318359375}, {'x': 0...        0.14   1.000000
#
#     Comments  Internal Notes
# 0        NaN             NaN
# 1        NaN             NaN
# 2        NaN             NaN
# 3        NaN             NaN
# 4        NaN             NaN
# ..       ...             ...
# 589      NaN             NaN
# 590      NaN             NaN
# 602      NaN             NaN
# 608      NaN             NaN
# 609      NaN             NaN
#
# [582 rows x 14 columns]

# %%
Epi.tail(30)
# Out:
#           0       1    2               3           4            5   \
# 554  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 555  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 556  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 557  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 558  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 559  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 560  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 561  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 562  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 563  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 564  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 565  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 566  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 567  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 568  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 569  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 570  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 571  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 572  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 573  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 574  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 575  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 576  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 577  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 578  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 579  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 580  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 581  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 582  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
# 583  Case ID  Origin  URL  Labeling State  All Labels  Total Reads
#
#                         6               7               8              9   \
# 554  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 555  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 556  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 557  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 558  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 559  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 560  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 561  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 562  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 563  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 564  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 565  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 566  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 567  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 568  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 569  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 570  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 571  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 572  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 573  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 574  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 575  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 576  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 577  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 578  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 579  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 580  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 581  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 582  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
# 583  Total Qualified Reads  Majority Label  Number of ROIs  Correct Label
#
#              10         11        12              13
# 554  Difficulty  Agreement  Comments  Internal Notes
# 555  Difficulty  Agreement  Comments  Internal Notes
# 556  Difficulty  Agreement  Comments  Internal Notes
# 557  Difficulty  Agreement  Comments  Internal Notes
# 558  Difficulty  Agreement  Comments  Internal Notes
# 559  Difficulty  Agreement  Comments  Internal Notes
# 560  Difficulty  Agreement  Comments  Internal Notes
# 561  Difficulty  Agreement  Comments  Internal Notes
# 562  Difficulty  Agreement  Comments  Internal Notes
# 563  Difficulty  Agreement  Comments  Internal Notes
# 564  Difficulty  Agreement  Comments  Internal Notes
# 565  Difficulty  Agreement  Comments  Internal Notes
# 566  Difficulty  Agreement  Comments  Internal Notes
# 567  Difficulty  Agreement  Comments  Internal Notes
# 568  Difficulty  Agreement  Comments  Internal Notes
# 569  Difficulty  Agreement  Comments  Internal Notes
# 570  Difficulty  Agreement  Comments  Internal Notes
# 571  Difficulty  Agreement  Comments  Internal Notes
# 572  Difficulty  Agreement  Comments  Internal Notes
# 573  Difficulty  Agreement  Comments  Internal Notes
# 574  Difficulty  Agreement  Comments  Internal Notes
# 575  Difficulty  Agreement  Comments  Internal Notes
# 576  Difficulty  Agreement  Comments  Internal Notes
# 577  Difficulty  Agreement  Comments  Internal Notes
# 578  Difficulty  Agreement  Comments  Internal Notes
# 579  Difficulty  Agreement  Comments  Internal Notes
# 580  Difficulty  Agreement  Comments  Internal Notes
# 581  Difficulty  Agreement  Comments  Internal Notes
# 582  Difficulty  Agreement  Comments  Internal Notes
# 583  Difficulty  Agreement  Comments  Internal Notes
